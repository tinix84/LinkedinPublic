# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np 
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## EMC

# %%
import emc.test_limits
emc.test_limits.test_emc_ac()
# Out:
# No PK limit available for this standard
# Frequency: 1.00e+06 the average limit is 46.0 dBuV
# Frequency: 1.00e+06 the quasi-peak limit is 56.0 dBuV

# %%
from analysis.emc.limits_old import TL81000_2018_03_AN

avg_limit, qp_limit, pk_limit, dbuV_avg_limit, dbuV_qp_limit, dbuV_pk_limit = TL81000_2018_03_AN(emc_class=5).interp_log(fm)
# Out:
# No QP limit available for this standard

# %%
import emc.test_limits

fmmin = 150e3
fmmax = 30e6
fstep=1e3
fm = np.arange(fmmin, fmmax, fstep)
dt = 1/2/fmmax

emc.test_limits.calc_worst_case_emc_limits(fm=fm, att_margin=0.0, debug_plot=True)
# Out:
# No QP limit available for this standard
# No PK limit available for this standard
# No PK limit available for this standard

# %%
from emc import test_emc

f_hmax_energy, hmax_energy, spectum_energy, \
    f_signal, c_signal, emc_spectrum, \
        new_time, new_signal_wfm, \
            spectrum_avg, spectrum_pk = test_emc.test_calc_emc_params_plot()
# test_emc.test_cispr16_detector()
# Out:
# /home/tinix84/ntbees/vishay-ac-dc/analysis/emc/emc.py:68: RuntimeWarning: divide by zero encountered in log10
#   plt.semilogx(fm, 20 * np.log10(np.abs(spectrum_avg)), label='CISPR16_AV')
# /home/tinix84/ntbees/vishay-ac-dc/analysis/emc/emc.py:69: RuntimeWarning: divide by zero encountered in log10
#   plt.semilogx(fm, 20 * np.log10(np.abs(spectrum_pk)), label='CISPR16_PK')
# /home/tinix84/ntbees/vishay-ac-dc/analysis/emc/emc.py:70: RuntimeWarning: divide by zero encountered in log10
#   plt.legend(loc='best')

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(new_time, new_signal_wfm)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.semilogx(f_signal, 20 * np.log10(np.abs(c_signal)), label='FFT')
plt.semilogx(f_signal, 20 * np.log10(np.abs(emc_spectrum)), label='EMC')
plt.legend()
# Out:
# /tmp/ipykernel_11816/1961328045.py:4: RuntimeWarning: divide by zero encountered in log10
#   plt.semilogx(f_signal, 20 * np.log10(np.abs(emc_spectrum)), label='EMC')

# %%
from emc import test_emc

test_emc.test_calc_emc_worstpeak()
